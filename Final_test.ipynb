# %%
#importing the libraries:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
#loading data:
data=pd.read_csv(r"C:\Users\HP\Downloads\data_car.csv")

# %%
data.head(2)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650

# %%
#Exploratory Data Analysis:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
data.shape
# Out:
# (11914, 16)

# %%
##check for null values:
data.isna().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
#check the min,max,std etc:
data.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %%
data.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
#Checking unique values:

# %%
data["Year"].nunique()
# Out:
# 28

# %%
data["Engine HP"].nunique()
# Out:
# 356

# %%
data["Engine Fuel Type"].nunique()
# Out:
# 10

# %%
data["Engine Cylinders"].nunique()
# Out:
# 9

# %%
data["Transmission Type"].nunique()
# Out:
# 5

# %%
data["Driven_Wheels"].nunique()
# Out:
# 4

# %%
data["Number of Doors"].nunique()
# Out:
# 3

# %%
data["Market Category"].nunique()
# Out:
# 71

# %%
data["Vehicle Size"].nunique()
# Out:
# 3

# %%
data["Vehicle Style"].nunique()
# Out:
# 16

# %%
data["highway MPG"].nunique()
# Out:
# 59

# %%
data["city mpg"].nunique()
# Out:
# 69

# %%
data["Popularity"].nunique()
# Out:
# 48

# %%
data["MSRP"].nunique()
# Out:
# 6049

# %%
plt.figure(figsize=(10,10))
corr_matrx=data.corr()
sns.heatmap(corr_matrx,annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
##frequency graph:
freqgraph=data.select_dtypes(include=['int','float'])
freqgraph.hist(figsize=(20,15))
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
num_cols=['Year','Engine HP','Engine Cylinders','Number of Doors','highway MPG','city mpg','Popularity','MSRP']

# %%
cat_cols=['Make','Model','Engine Fuel Type','Transmission Type','Driven_Wheels','Market Category']

# %%
#Box plot representation:
sns.boxplot(x=data['Engine HP'])
plt.show()
sns.boxplot(x=data['Year'])
plt.show()
sns.boxplot(x=data['Engine Cylinders'])
plt.show()
sns.boxplot(x=data['Number of Doors'])
plt.show()
sns.boxplot(x=data['highway MPG'])
plt.show()
sns.boxplot(x=data['city mpg'])
plt.show()
sns.boxplot(x=data['Popularity'])
plt.show()
sns.boxplot(x=data['MSRP'])
plt.show()

# %%
sns.boxplot(x=data['Make])
plt.show()
# Out:
#   Input In [80]
#     sns.boxplot(x=data['Make])
#                               ^
# SyntaxError: EOL while scanning string literal

# %%
#Pre-processing

# %%
#Handling missing values:

# %%
data.isna().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
num_cols
# Out:
# ['Year',
#  'Engine HP',
#  'Engine Cylinders',
#  'Number of Doors',
#  'highway MPG',
#  'city mpg',
#  'Popularity',
#  'MSRP']

# %%
data['Engine Cylinders']=data['Engine Cylinders'].fillna(data['Engine Cylinders'].median())

# %%
data['Engine HP']=data['Engine HP'].fillna(data['Engine HP'].median())

# %%
data['Number of Doors']=data['Number of Doors'].fillna(data['Number of Doors'].median())

# %%
data['Engine Fuel Type']=data['Engine Fuel Type'].fillna(data['Engine Fuel Type'].mode())

# %%
data.isna().sum()
# Out:
# Make                     0
# Model                    0
# Year                     0
# Engine Fuel Type     11914
# Engine HP                0
# Engine Cylinders         0
# Transmission Type        0
# Driven_Wheels            0
# Number of Doors          0
# Market Category      11914
# Vehicle Size             0
# Vehicle Style            0
# highway MPG              0
# city mpg                 0
# Popularity               0
# MSRP                     0
# dtype: int64

# %%
data['Engine Fuel Type'].fillna('Missing', inplace=True)

# %%
data['Market Category'].fillna('Missing', inplace=True)

# %%
data.isna().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine Fuel Type     0
# Engine HP            0
# Engine Cylinders     0
# Transmission Type    0
# Driven_Wheels        0
# Number of Doors      0
# Market Category      0
# Vehicle Size         0
# Vehicle Style        0
# highway MPG          0
# city mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %%
#Handling Outliers:

# %%
#Engine HP

# %%
data.rename(columns={'Engine Fuel Type':'Engine_Fuel_Type'},inplace=True)
data.rename(columns={'Engine HP':'Engine_HP'},inplace=True)
data.rename(columns={'Engine Cylinders':'Engine_Cylinders'},inplace=True)
data.rename(columns={'Transmission Type':'Transmission_Type'},inplace=True)
data.rename(columns={'Market Category':'Market_Category'},inplace=True)
data.rename(columns={'Vehicle Size':'Vehicle_Size'},inplace=True)
data.rename(columns={'Vehicle Style':'Vehicle_Style'},inplace=True)
data.rename(columns={'highway MPG':'highway_MPG'},inplace=True)
data.rename(columns={'city mpg':'city_mpg'},inplace=True)

# %%
IQR=stats.iqr(data.Engine_HP,interpolation="midpoint")
IQR
# Out:
# 130.0

# %%
Q1=data.Engine_HP.quantile(0.25)
Q3=data.Engine_HP.quantile(0.75)
min_limit=Q1-1.5*IQR
max_limit=Q3+1.5*IQR
min_limit,max_limit
# Out:
# (-25.0, 495.0)

# %%
data.loc[data.Engine_HP>max_limit]
# Out:
#           Make       Model  Year Engine_Fuel_Type  Engine_HP  \
# 466    Ferrari  458 Italia  2013          Missing      562.0
# 467    Ferrari  458 Italia  2013          Missing      562.0
# 468    Ferrari  458 Italia  2014          Missing      562.0
# 469    Ferrari  458 Italia  2014          Missing      597.0
# 470    Ferrari  458 Italia  2014          Missing      562.0
# ...        ...         ...   ...              ...        ...
# 11509      BMW        X5 M  2016          Missing      567.0
# 11510      BMW        X5 M  2017          Missing      567.0
# 11523      BMW        X6 M  2015          Missing      567.0
# 11524      BMW        X6 M  2016          Missing      567.0
# 11525      BMW        X6 M  2017          Missing      567.0
#
#        Engine_Cylinders Transmission_Type     Driven_Wheels  Number of Doors  \
# 466                 8.0  AUTOMATED_MANUAL  rear wheel drive              2.0
# ...

# %%
data.loc[data.Engine_HP<min_limit]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine_Fuel_Type, Engine_HP, Engine_Cylinders, Transmission_Type, Driven_Wheels, Number of Doors, Market_Category, Vehicle_Size, Vehicle_Style, highway_MPG, city_mpg, Popularity, MSRP]
# Index: []

# %%
data.loc[data["Engine_HP"]>max_limit,"Engine_HP"]=np.mean(data.Engine_HP)

# %%
data.loc[data.Engine_HP>max_limit]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine_Fuel_Type, Engine_HP, Engine_Cylinders, Transmission_Type, Driven_Wheels, Number of Doors, Market_Category, Vehicle_Size, Vehicle_Style, highway_MPG, city_mpg, Popularity, MSRP]
# Index: []

# %%
#Year :

# %%
IQR=stats.iqr(data.Year,interpolation="midpoint")
IQR
# Out:
# 9.0

# %%
Q1=data.Year.quantile(0.25)
Q3=data.Year.quantile(0.75)
min_limit=Q1-1.5*IQR
max_limit=Q3+1.5*IQR
min_limit,max_limit
# Out:
# (1993.5, 2029.5)

# %%
data.loc[data.Year>max_limit]
data.loc[data.Year<min_limit]
# Out:
#          Make  Model  Year Engine_Fuel_Type  Engine_HP  Engine_Cylinders  \
# 17       Audi    100  1992          Missing      172.0               6.0
# 18       Audi    100  1992          Missing      172.0               6.0
# 19       Audi    100  1992          Missing      172.0               6.0
# 20       Audi    100  1992          Missing      172.0               6.0
# 21       Audi    100  1992          Missing      172.0               6.0
# ...       ...    ...   ...              ...        ...               ...
# 11376   Acura  Vigor  1993          Missing      176.0               5.0
# 11377   Acura  Vigor  1993          Missing      176.0               5.0
# 11792  Subaru     XT  1991          Missing       97.0               4.0
# 11793  Subaru     XT  1991          Missing      145.0               6.0
# 11794  Subaru     XT  1991          Missing      145.0               6.0
#
#       Transmission_Type      Driven_Wheels  Number of Doors Market_Category  \
# ...

# %%
data.loc[data["Year"]>max_limit,"Year"]=np.mean(data.Year)

# %%
data.loc[data.Year>max_limit]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine_Fuel_Type, Engine_HP, Engine_Cylinders, Transmission_Type, Driven_Wheels, Number of Doors, Market_Category, Vehicle_Size, Vehicle_Style, highway_MPG, city_mpg, Popularity, MSRP]
# Index: []

# %%
#Engine_Cylinders:

# %%
IQR=stats.iqr(data.Engine_Cylinders,interpolation="midpoint")
IQR
# Out:
# 2.0

# %%
Q1=data.Engine_Cylinders.quantile(0.25)
Q3=data.Engine_Cylinders.quantile(0.75)
min_limit=Q1-1.5*IQR
max_limit=Q3+1.5*IQR
min_limit,max_limit
# Out:
# (1.0, 9.0)

# %%
data.loc[data.Engine_Cylinders>max_limit]
data.loc[data.Engine_Cylinders<min_limit]
# Out:
#                Make                   Model  Year Engine_Fuel_Type  Engine_HP  \
# 539            FIAT                    500e  2015          Missing      227.0
# 540            FIAT                    500e  2016          Missing      227.0
# 541            FIAT                    500e  2017          Missing      227.0
# 1680  Mercedes-Benz  B-Class Electric Drive  2015          Missing      177.0
# 1681  Mercedes-Benz  B-Class Electric Drive  2016          Missing      177.0
# 1682  Mercedes-Benz  B-Class Electric Drive  2017          Missing      177.0
# 4705          Honda                  Fit EV  2013          Missing      227.0
# 4706          Honda                  Fit EV  2014          Missing      227.0
# 4785           Ford                   Focus  2015          Missing      227.0
# 4789           Ford                   Focus  2016          Missing      227.0
# 4798           Ford                   Focus  2017          Missing      227.0
# ...

# %%
data.loc[data["Engine_Cylinders"]>max_limit,"Engine_Cylinders"]=np.mean(data.Year)

# %%
data.loc[data.Year>max_limit]
# Out:
#           Make       Model  Year Engine_Fuel_Type  Engine_HP  \
# 0          BMW  1 Series M  2011          Missing      335.0
# 1          BMW    1 Series  2011          Missing      300.0
# 2          BMW    1 Series  2011          Missing      300.0
# 3          BMW    1 Series  2011          Missing      230.0
# 4          BMW    1 Series  2011          Missing      230.0
# ...        ...         ...   ...              ...        ...
# 11909    Acura         ZDX  2012          Missing      300.0
# 11910    Acura         ZDX  2012          Missing      300.0
# 11911    Acura         ZDX  2012          Missing      300.0
# 11912    Acura         ZDX  2013          Missing      300.0
# 11913  Lincoln      Zephyr  2006          Missing      221.0
#
#        Engine_Cylinders Transmission_Type      Driven_Wheels  Number of Doors  \
# 0                   6.0            MANUAL   rear wheel drive              2.0
# ...

# %%
#highway_MPG

# %%
IQR=stats.iqr(data.highway_MPG,interpolation="midpoint")
Q1=data.highway_MPG.quantile(0.25)
Q3=data.highway_MPG.quantile(0.75)
min_limit=Q1-1.5*IQR
max_limit=Q3+1.5*IQR
min_limit,max_limit
# Out:
# (10.0, 42.0)

# %%
data.loc[data.highway_MPG>max_limit]
data.loc[data.highway_MPG<min_limit]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine_Fuel_Type, Engine_HP, Engine_Cylinders, Transmission_Type, Driven_Wheels, Number of Doors, Market_Category, Vehicle_Size, Vehicle_Style, highway_MPG, city_mpg, Popularity, MSRP]
# Index: []

# %%
data.loc[data["highway_MPG"]>max_limit,"highway_MPG"]=np.mean(data.Year)

# %%
data.loc[data.highway_MPG>max_limit]
# Out:
#            Make     Model  Year Engine_Fuel_Type  Engine_HP  Engine_Cylinders  \
# 135         BMW  3 Series  2015          Missing      180.0               4.0
# 140         BMW  3 Series  2015          Missing      180.0               4.0
# 142         BMW  3 Series  2015          Missing      180.0               4.0
# 539        FIAT      500e  2015          Missing      227.0               0.0
# 540        FIAT      500e  2016          Missing      227.0               0.0
# ...         ...       ...   ...              ...        ...               ...
# 9868  Chevrolet  Spark EV  2014          Missing      140.0               0.0
# 9869  Chevrolet  Spark EV  2015          Missing      140.0               0.0
# 9870  Chevrolet  Spark EV  2015          Missing      140.0               0.0
# 9871  Chevrolet  Spark EV  2016          Missing      140.0               0.0
# 9872  Chevrolet  Spark EV  2016          Missing      140.0               0.0
#
# ...

# %%
#Modelling

# %%
data.head(2)
# Out:
#   Make       Model  Year Engine_Fuel_Type  Engine_HP  Engine_Cylinders  \
# 0  BMW  1 Series M  2011          Missing      335.0               6.0
# 1  BMW    1 Series  2011          Missing      300.0               6.0
#
#   Transmission_Type     Driven_Wheels  Number of Doors Market_Category  \
# 0            MANUAL  rear wheel drive              2.0         Missing
# 1            MANUAL  rear wheel drive              2.0         Missing
#
#   Vehicle_Size Vehicle_Style  highway_MPG  city_mpg  Popularity   MSRP
# 0      Compact         Coupe         26.0        19        3916  46135
# 1      Compact   Convertible         28.0        19        3916  40650

# %%
y=data['MSRP']
x=data.drop(['MSRP'],axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
rf_clf=RandomForestClassifier()
rf_clf.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [166], in <cell line: 3>()
#       1 from sklearn.ensemble import RandomForestClassifier
#       2 rf_clf=RandomForestClassifier()
# ----> 3 rf_clf.fit(x_train,y_train)
#
# File ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:327, in BaseForest.fit(self, X, y, sample_weight)
#     325 if issparse(y):
#     326     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 327 X, y = self._validate_data(
#     328     X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     329 )
#     330 if sample_weight is not None:
#     331     sample_weight = _check_sample_weight(sample_weight, X)
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:581, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     579         y = check_array(y, **check_y_params)
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
data[]
